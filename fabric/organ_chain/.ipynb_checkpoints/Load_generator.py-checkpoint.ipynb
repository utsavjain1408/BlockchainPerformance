# %%
import os

# %%
def create_peer_invoke_command():
    base = "docker exec -it cli peer chaincode invoke -o orderer.organ.com:7050 --tls true --cafile /opt/gopath/src/github.com/hyperledger/fabric/peer/crypto/ordererOrganizations/organ.com/orderers/orderer.organ.com/msp/tlscacerts/tlsca.organ.com-cert.pem -C organ-channel -n organcc "
    return(base)

def add_peers(org='hl', peer_n=0):
    hl_p1_add = ' --peerAddresses peer1.histocompatibility.organ.com:7051 '
    hl_p1_cert = ' --tlsRootCertFiles /opt/gopath/src/github.com/hyperledger/fabric/peer/crypto/peerOrganizations/histocompatibility.organ.com/peers/peer1.histocompatibility.organ.com/tls/ca.crt '
    hl_p0_add = ' --peerAddresses peer0.histocompatibility.organ.com:7051 '
    hl_p0_cert = ' --tlsRootCertFiles /opt/gopath/src/github.com/hyperledger/fabric/peer/crypto/peerOrganizations/histocompatibility.organ.com/peers/peer0.histocompatibility.organ.com/tls/ca.crt '
    
    ho_p1_add = ' --peerAddresses peer1.hospital.organ.com:7051 '
    ho_p1_cert = ' --tlsRootCertFiles /opt/gopath/src/github.com/hyperledger/fabric/peer/crypto/peerOrganizations/hospital.organ.com/peers/peer1.hospital.organ.com/tls/ca.crt  '
    ho_p0_add = ' --peerAddresses peer0.hospital.organ.com:7051 '
    ho_p0_cert = ' --tlsRootCertFiles /opt/gopath/src/github.com/hyperledger/fabric/peer/crypto/peerOrganizations/hospital.organ.com/peers/peer0.hospital.organ.com/tls/ca.crt  '
    
    gp_p1_add = ' --peerAddresses peer1.gp.organ.com:7051 '
    gp_p1_cert = ' --tlsRootCertFiles /opt/gopath/src/github.com/hyperledger/fabric/peer/crypto/peerOrganizations/gp.organ.com/peers/peer1.gp.organ.com/tls/ca.crt  '
    gp_p0_add = ' --peerAddresses peer0.gp.organ.com:7051 '
    gp_p0_cert = ' --tlsRootCertFiles /opt/gopath/src/github.com/hyperledger/fabric/peer/crypto/peerOrganizations/gp.organ.com/peers/peer0.gp.organ.com/tls/ca.crt  '
    
    op_p1_add = ' --peerAddresses peer1.opo.organ.com:7051 '
    op_p1_cert = ' --tlsRootCertFiles /opt/gopath/src/github.com/hyperledger/fabric/peer/crypto/peerOrganizations/opo.organ.com/peers/peer1.opo.organ.com/tls/ca.crt  '
    op_p0_add = ' --peerAddresses peer0.opo.organ.com:7051 '
    op_p0_cert = ' --tlsRootCertFiles /opt/gopath/src/github.com/hyperledger/fabric/peer/crypto/peerOrganizations/opo.organ.com/peers/peer0.opo.organ.com/tls/ca.crt  '
    cmd = ""
    cmd += create_peer_invoke_command() + hl_p1_add + hl_p1_cert +hl_p0_add + hl_p0_cert
    cmd += ho_p0_add + ho_p0_cert + ho_p1_add + ho_p1_cert
    cmd += gp_p0_add + gp_p0_cert + gp_p1_add + gp_p1_cert
    cmd += op_p0_add + op_p0_cert + op_p1_add + op_p1_cert
    return(cmd)

def add_organ(organ_id = '', organ_name='', organ_data=''):
    cmd = add_peers() + '-c '
    
    cmd += '\'{"Args":["initOrgan", "' + organ_id + '", "' + organ_name + '", ' + organ_data + ']}\''
#     cmd +=  '\'{\"Args\":[\"readOrgan",\"' + str(organ_id) + '\"]}\''
#     cmd += '-c \'{\"Args\":[\"initOrgan\", \"' + str(organ_id) + '\", \"' + str(organ_name) + '\", \"'+ str(organ_data) +'\"]}\''
#     cmd += '-c \'{"Args":["initOrgan", "' + str(organ_id) + '", "' + str(organ_name) + '", '+ str(organ_data) +']}\''

    return(cmd)

def read_organ(organ_id='421'):
    cmd = add_peers()
    cmd +=  '-c \'{\"Args\":[\"readOrgan",\"' + str(organ_id) + '\"]}\''
    return(cmd)

def add_candidate(candidate_id = '', organ_name='', info=''):
    cmd = add_peers()
#     cmd +=  '\'{\"Args\":[\"readOrgan",\"' + str(organ_id) + '\"]}\''
#     cmd += '-c \'{\"Args\":[\"initOrgan\", \"' + str(organ_id) + '\", \"' + str(organ_name) + '\", \"'+ str(organ_data) +'\"]}\''
    cmd += '-c \'{\"Args\":[\"initCandidate\", "' + str(candidate_id) + '", "' + str(organ_name) + '", "'+ str(info) +'"]}\''

    return(cmd)

def read_candidate(candidate_id='421'):
    cmd = add_peers()
    cmd +=  '-c \'{\"Args\":[\"readCandidate",\"' + str(candidate_id) + '\"]}\''
    return(cmd)

# cmd = add_organ("422", "inf", "some data with spaces")
cmd = read_organ(422)
print(cmd)
for i in range(10):
    # !{"echo $?" +str(i)}
# !{cmd}
# x=!{"echo $?"}
# print(x)
# Out:
# docker exec -it cli peer chaincode invoke -o orderer.organ.com:7050 --tls true --cafile /opt/gopath/src/github.com/hyperledger/fabric/peer/crypto/ordererOrganizations/organ.com/orderers/orderer.organ.com/msp/tlscacerts/tlsca.organ.com-cert.pem -C organ-channel -n organcc  --peerAddresses peer1.histocompatibility.organ.com:7051  --tlsRootCertFiles /opt/gopath/src/github.com/hyperledger/fabric/peer/crypto/peerOrganizations/histocompatibility.organ.com/peers/pe
UTC [msp.identity] Sign -> DEBU 0a1 Sign: digest: 80A266BCD9F079010EBE435B7DD6068B60A1ECDF1A2DE0642BB67B438C700177
# 2019-04-15 07:31:10.863 UTC [chaincodeCmd] chaincodeInvokeOrQuery -> DEBU 0a2 ESCC invoke result: version:1 response:<status:200 payload:"{\"docType\":\"organ\",\"organID\":\"422\",\"type\":\"inf\",\"donorInfo\":\"some data with spaces\",\"owner\":\"Donor\"}" > payload:"\n \260\014\271\210\210OE{\214QE\301Zw\007Z?\221\327\227\251\373(\364\205\001c\022\002\016\td\022\256\001\n1\022\027\n\004lscc\022\017\n\r\n\007organcc\022\002\010\005\022\026\n\007organcc\022\013\n\t\n\003422\022\002\0101\032i\010\310\001\032d{\"docType\":\"organ\",\"organID\":\"422\",\"type\":\"inf\",\"donorInfo\":\"some data with spaces\",\"owner\":\"Donor\"}\"\016\022\007organcc\032\0031.0" endorsement:<endorser:"\n\005HLMSP\022\333\006-----BEGIN CERTIFICATE-----\\n-----END CERTIFICATE-----\n" signature:"0D\002 ,\351\177\"\031R\312\264 \005:\321\335\212\3445\364\274\250m)S\001\311\207Z\325\322\027\350^\201\002 |vXb1^\365\343Mv+\334`\033\033x\3011\337\203\017nv\342\356\273\361`\0174Pg" >
# 2019-04-15 07:31:10.864 UTC [chaincodeCmd] chaincodeInvokeOrQuery -> INFO 0a3 Chaincode invoke successful. result: status:200 payload:"{\"docType\":\"organ\",\"organID\":\"422\",\"type\":\"inf\",\"donorInfo\":\"some data with spaces\",\"owner\":\"Donor\"}"

# %%
import re
with open(r"/home/thesis/Downloads/data_1.json", 'r') as file:
    data_1 = file.read()
with open(r"/home/thesis/Downloads/data_2.json", 'r') as file:
    data_2 = file.read()
with open(r"/home/thesis/Downloads/data_3.json", 'r') as file:
    data_3 = file.read()
with open(r"/home/thesis/Downloads/data_4.json", 'r') as file:
    data_4 = file.read()
    
import json

data_1 = json.dumps(data_1)
data_2 = json.dumps(data_2)
data_3 = json.dumps(data_3)
data_4 = json.dumps(data_4)

# print((data_1))

# %%
cmd = add_organ("1231", "heard", data_1)

# cmd += '\'{"Args":["initOrgan", "152", "heart", ' + data_1 + ']}\''
# cmd = read_organ(422)
# print(cmd)
! {cmd}
# Out:
# 2019-04-15 07:31:54.161 UTC [viperutil] getKeysRecursively -> DEBU 001 Found map[string]interface{} value for peer.BCCSP
# 2019-04-15 07:31:54.161 UTC [viperutil] getKeysRecursively -> DEBU 002 Found map[string]interface{} value for peer.BCCSP.SW
# 2019-04-15 07:31:54.162 UTC [viperutil] unmarshalJSON -> DEBU 003 Unmarshal JSON: value cannot be unmarshalled: invalid character 'S' looking for beginning of value
# 2019-04-15 07:31:54.162 UTC [viperutil] getKeysRecursively -> DEBU 004 Found real value for peer.BCCSP.SW.Hash setting to string SHA2
# 2019-04-15 07:31:54.162 UTC [viperutil] unmarshalJSON -> DEBU 005 Unmarshal JSON: value is not a string: 256
# 2019-04-15 07:31:54.162 UTC [viperutil] getKeysRecursively -> DEBU 006 Found real value for peer.BCCSP.SW.Security setting to int 256
# 2019-04-15 07:31:54.162 UTC [viperutil] getKeysRecursively -> DEBU 007 Found map[string]interface{} value for peer.BCCSP.SW.FileKeyStore
# 2019-04-15 07:31:54.162 UTC [viperutil] unmarshalJSON -> DEBU 008 Unmarshal JSON: value cannot be unmarshalled: unexpected end of JSON input
# 2019-04-15 07:31:54.162 UTC [viperutil] getKeysRecursively -> DEBU 009 Found real value for peer.BCCSP.SW.FileKeyStore.KeyStore setting to string
# 2019-04-15 07:31:54.162 UTC [viperutil] getKeysRecursively -> DEBU 00a Found map[string]interface{} value for peer.BCCSP.PKCS11
# 2019-04-15 07:31:54.163 UTC [viperutil] unmarshalJSON -> DEBU 00b Unmarshal JSON: value is not a string: <nil>
# 2019-04-15 07:31:54.163 UTC [viperutil] getKeysRecursively -> DEBU 00c Found real value for peer.BCCSP.PKCS11.Library setting to <nil> <nil>
# 2019-04-15 07:31:54.163 UTC [viperutil] unmarshalJSON -> DEBU 00d Unmarshal JSON: value is not a string: <nil>
# 2019-04-15 07:31:54.163 UTC [viperutil] getKeysRecursively -> DEBU 00e Found real value for peer.BCCSP.PKCS11.Label setting to <nil> <nil>
# 2019-04-15 07:31:54.164 UTC [viperutil] unmarshalJSON -> DEBU 00f Unmarshal JSON: value is not a string: <nil>
# 2019-04-15 07:31:54.164 UTC [viperutil] getKeysRecursively -> DEBU 010 Found real value for peer.BCCSP.PKCS11.Pin setting to <nil> <nil>
# 2019-04-15 07:31:54.164 UTC [viperutil] unmarshalJSON -> DEBU 011 Unmarshal JSON: value is not a string: <nil>
# 2019-04-15 07:31:54
UTC [grpc] HandleSubConnStateChange -> DEBU 06b pickfirstBalancer: HandleSubConnStateChange: 0xc000135fe0, CONNECTING
# 2019-04-15 07:31:54.225 UTC [grpc] HandleSubConnStateChange -> DEBU 06c pickfirstBalancer: HandleSubConnStateChange: 0xc000135fe0, READY
# 2019-04-15 07:31:54.226 UTC [grpc] DialContext -> DEBU 06d parsed scheme: ""
# 2019-04-15 07:31:54.227 UTC [grpc] DialContext -> DEBU 06e scheme "" not registered, fallback to default scheme
# 2019-04-15 07:31:54.227 UTC [grpc] watcher -> DEBU 06f ccResolverWrapper: sending new addresses to cc: [{peer0.gp.organ.com:7051 0  <nil>}]
# 2019-04-15 07:31:54.227 UTC [grpc] switchBalancer -> DEBU 070 ClientConn switching balancer to "pick_first"
# 2019-04-15 07:31:54.227 UTC [grpc] HandleSubConnStateChange -> DEBU 071 pickfirstBalancer: HandleSubConnStateChange: 0xc00013c250, CONNECTING
# 2019-04-15 07:31:54.242 UTC [grpc] HandleSubConnStateChange -> DEBU 072 pickfirstBalancer: HandleSubConnStateChange: 0xc00013c250, READY
# 2019-04-15 07:31:54.244 UTC [grpc] DialContext -> DEBU 073 parsed scheme: ""
# 2019-04-15 07:31:54.244 UTC [grpc] DialContext -> DEBU 074 scheme "" not registered, fallback to default scheme
# 2019-04-15 07:31:54.244 UTC [grpc] watcher -> DEBU 075 ccResolverWrapper: sending new addresses to cc: [{peer1.gp.organ.com:7051 0  <nil>}]
# 2019-04-15 07:31:54.244 UTC [grpc] switchBalancer -> DEBU 076 ClientConn switching balancer to "pick_first"
# 2019-04-15 07:31:54.244 UTC [grpc] HandleSubConnStateChange -> DEBU 077 pickfirstBalancer: HandleSubConnStateChange: 0xc000368b90, CONNECTING
# 2019-04-15 07:31:54.247 UTC [grpc] HandleSubConnStateChange -> DEBU 078 pickfirstBalancer: HandleSubConnStateChange: 0xc000368b90, READY
# 2019-04-15 07:31:54.248 UTC [grpc] DialContext -> DEBU 079 parsed scheme: ""
# 2019-04-15 07:31:54.248 UTC [grpc] DialContext -> DEBU 07a scheme "" not registered, fallback to default scheme
# 2019-04-15 07:31:54.248 UTC [grpc] watcher -> DEBU 07b ccResolverWrapper: sending new addresses to cc: [{peer1.gp.organ.com:7051 0  <nil>}]
# 2019-04-15 07:31:54.248 UTC [grpc] switchBalancer -> DEBU 07c ClientConn switching balancer to "pick_first"
# 2019-04-15 07:31:54.249 UTC [grpc] HandleSubConnStateChange -> DEBU 07d pickfirstBalancer: HandleSubConnStateChange: 0xc0003e9c60, CONNECTING
# 2019-04-15 07:31:54.252 UTC [grpc] HandleSubConnStateChange -> DEBU 07e pickfirstBalancer: HandleSubConnStateChange: 0xc0003e9c60, READY
# 2019-04-15 07:31:54.252 UTC [grpc] DialContext -> DEBU 07f parsed scheme: ""
# 2019-04-15 07:31:54.252 UTC [grpc] DialContext -> DEBU 080 scheme "" not registered, fallback to default scheme
# 2019-04-15 07:31:54.252 UTC [grpc] watcher -> DEBU 081 ccResolverWrapper: sending new addresses to cc: [{peer0.opo.organ.com:7051 0  <nil>}]
# 2019-04-15 07:31:54.252 UTC [grpc] switchBalancer -> DEBU 082 ClientConn switching balancer to "pick_first"
# 2019-04-15 07:31:54.252 UTC [grpc] HandleSubConnStateChange -> DEBU 083 pickfirstBalancer: HandleSubConnStateChange: 0xc0004c46b0, CONNECTING
# 2019-04-15 07:31:54.258 UTC [grpc] HandleSubConnStateChange -> DEBU 084 pickfirstBalancer: HandleSubConnStateChange: 0xc0004c46b0, READY
# 2019-04-15 07:31:54.259 UTC [grpc] DialContext -> DEBU 085 parsed scheme: ""
# 2019-04-15 07:31:54.259 UTC [grpc] DialContext -> DEBU 086 scheme "" not registered, fallback to default scheme
# 2019-04-15 07:31:54.259 UTC [grpc] watcher -> DEBU 087 ccResolverWrapper: sending new addresses to cc: [{peer0.opo.organ.com:7051 0  <nil>}]
# 2019-04-15 07:31:54.259 UTC [grpc] switchBalancer -> DEBU 088 ClientConn switching balancer to "pick_first"
# 2019-04-15 07:31:54.259 UTC [grpc] HandleSubConnStateChange -> DEBU 089 pickfirstBalancer: HandleSubConnStateChange: 0xc000553520, CONNECTING
# 2019-04-15 07:31:54.263 UTC [grpc] HandleSubConnStateChange -> DEBU 08a pickfirstBalancer: HandleSubConnStateChange: 0xc000553520, READY
# 2019-04-15 07:31:54.265 UTC [grpc] DialContext -> DEBU 08b parsed scheme: ""
# 2019-04-15 07:31:54.265 UTC [grpc] DialContext -> DEBU 08c scheme "" not registered, fallback to default scheme
# 2019-04-15 07:31:54.265 UTC [grpc] watcher -> DEBU 08d ccResolverWrapper: sending new addresses to cc: [{peer1.opo.organ.com:7051 0  <nil>}]
# 2019-04-15 07:31:54.266 UTC [grpc] switchBalancer -> DEBU 08e ClientConn switching balancer to "pick_first"
# 2019-04-15 07:31:54.266 UTC [grpc] HandleSubConnStateChange -> DEBU 08f pickfirstBalancer: HandleSubConnStateChange: 0xc0005537c0, CONNECTING
# 2019-04-15 07:31:54.269 UTC [grpc] HandleSubConnStateChange -> DEBU 090 pickfirstBalancer: HandleSubConnStateChange: 0xc0005537c0, READY
# 2019-04-15 07:31:54.270 UTC [grpc] DialContext -> DEBU 091 parsed scheme: ""
# 2019-04-15 07:31:54.270 UTC [grpc] DialContext -> DEBU 092 scheme "" not registered, fallback to default scheme
# 2019-04-15 07:31:54.270 UTC [grpc] watcher -> DEBU 093 ccResolverWrapper: sending new addresses to cc: [{peer1.opo.organ.com:7051 0  <nil>}]
# 2019-04-15 07:31:54.270 UTC [grpc] switchBalancer -> DEBU 094 ClientConn switching balancer to "pick_first"
# 2019-04-15 07:31:54.270 UTC [grpc] HandleSubConnStateChange -> DEBU 095 pickfirstBalancer: HandleSubConnStateChange: 0xc0002d3d20, CONNECTING
# 2019-04-15 07:31:54.284 UTC [grpc] HandleSubConnStateChange -> DEBU 096 pickfirstBalancer: HandleSubConnStateChange: 0xc0002d3d20, READY
# 2019-04-15 07:31:54.285 UTC [msp] GetDefaultSigningIdentity -> DEBU 097 Obtaining default signing identity
# 2019-04-15 07:31:54.285 UTC [grpc] DialContext -> DEBU 098 parsed scheme: ""
# 2019-04-15 07:31:54.285 UTC [grpc] DialContext -> DEBU 099 scheme "" not registered, fallback to default scheme
# 2019-04-15 07:31:54.285 UTC [grpc] watcher -> DEBU 09a ccResolverWrapper: sending new addresses to cc: [{orderer.organ.com:7050 0  <nil>}]
# 2019-04-15 07:31:54.285 UTC [grpc] switchBalancer -> DEBU 09b ClientConn switching balancer to "pick_first"
# 2019-04-15 07:31:54.285 UTC [grpc] HandleSubConnStateChange -> DEBU 09c pickfirstBalancer: HandleSubConnStateChange: 0xc0006d4300, CONNECTING
# 2019-04-15 07:31:54.289 UTC [grpc] HandleSubConnStateChange -> DEBU 09d pickfirstBalancer: HandleSubConnStateChange: 0xc0006d4300, READY
# 2019-04-15 07:31:54.292 UTC [msp.identity] Sign -> DEBU 09e Sign: plaintext: 0AD2070A6E08031A0C08EAE6D0E50510...5F4341445F444F4E223A20227947227D
# 2019-04-15 07:31:54.292 UTC [msp.identity] Sign -> DEBU 09f Sign: digest: 1488D78B43D315535AE5F705A719166E80A824875C12C1910C529FE8585ADAF2
# 2019-04-15 07:31:54.389 UTC [chaincodeCmd] chaincodeInvokeOrQuery -> DEBU 0a0 ESCC invoke result: response:<status:500 message:"transaction returned with failure: Error: This Organ already exists: 1231" >
# Error: endorsement failure during invoke. response: status:500 message:"transaction returned with failure: Error: This Organ already exists: 1231"

# %%
cmd = read_organ(1231)
! {cmd}
# Out:
# 2019-04-15 07:33:14.267 UTC [viperutil] getKeysRecursively -> DEBU 001 Found map[string]interface{} value for peer.BCCSP
# 2019-04-15 07:33:14.268 UTC [viperutil] getKeysRecursively -> DEBU 002 Found map[string]interface{} value for peer.BCCSP.PKCS11
# 2019-04-15 07:33:14.268 UTC [viperutil] unmarshalJSON -> DEBU 003 Unmarshal JSON: value is not a string: <nil>
# 2019-04-15 07:33:14.268 UTC [viperutil] getKeysRecursively -> DEBU 004 Found real value for peer.BCCSP.PKCS11.Library setting to <nil> <nil>
# 2019-04-15 07:33:14.268 UTC [viperutil] unmarshalJSON -> DEBU 005 Unmarshal JSON: value is not a string: <nil>
# 2019-04-15 07:33:14.269 UTC [viperutil] getKeysRecursively -> DEBU 006 Found real value for peer.BCCSP.PKCS11.Label setting to <nil> <nil>
# 2019-04-15 07:33:14.269 UTC [viperutil] unmarshalJSON -> DEBU 007 Unmarshal JSON: value is not a string: <nil>
# 2019-04-15 07:33:14.269 UTC [viperutil] getKeysRecursively -> DEBU 008 Found real value for peer.BCCSP.PKCS11.Pin setting to <nil> <nil>
# 2019-04-15 07:33:14.269 UTC [viperutil] unmarshalJSON -> DEBU 009 Unmarshal JSON: value is not a string: <nil>
# 2019-04-15 07:33:14.270 UTC [viperutil] getKeysRecursively -> DEBU 00a Found real value for peer.BCCSP.PKCS11.Hash setting to <nil> <nil>
# 2019-04-15 07:33:14.270 UTC [viperutil] unmarshalJSON -> DEBU 00b Unmarshal JSON: value is not a string: <nil>
# 2019-04-15 07:33:14.270 UTC [viperutil] getKeysRecursively -> DEBU 00c Found real value for peer.BCCSP.PKCS11.Security setting to <nil> <nil>
# 2019-04-15 07:33:14.270 UTC [viperutil] getKeysRecursively -> DEBU 00d Found map[string]interface{} value for peer.BCCSP.PKCS11.FileKeyStore
# 2019-04-15 07:33:14.270 UTC [viperutil] unmarshalJSON -> DEBU 00e Unmarshal JSON: value is not a string: <nil>
# 2019-04-15 07:33:14.271 UTC [viperutil] getKeysRecursively -> DEBU 00f Found real value for peer.BCCSP.PKCS11.FileKeyStore.KeyStore setting to <nil> <nil>
# 2019-04-15 07:33:14.271 UTC [viperutil] unmarshalJSON -> DEBU 010 Unmarshal JSON: value cannot be unmarshalled: invalid character 'S' looking for beginning of value
# 2019-04-15 07:33:14.271 UTC [viperutil] getKeysRecursively -> DEBU 011 Found real value for peer.BCCSP.Default setting to string SW
# 2019-04-15 07:33:14.271 UTC [viperutil] getKeysRecursively -> DEBU 012 Found map[string]interface{} value for peer.BCCSP.SW
# 2019-04-15 07:33:14.271 UTC [viperutil] unmarshalJSON -> DEBU 013 Unmarshal JSON: value cannot be unmarshalled: invalid character 'S' looking for beginning of value
# 2019-04-15 07:33:14.271 UTC [viperutil] getKeysRecursively -> DEBU 014 Found real value for peer.BCCSP.SW.Hash setting to string SHA2
# 2019-04-15 07:33:14.272 UTC [viperutil] unmarshalJSON -> DEBU 015 Unmarshal JSON: value is not a string: 256
# 2019-04-15 07:33:14.272 UTC [viperutil] getKeysRecursively -> DEBU 016 Found real value for peer.BCCSP.SW.Security setting to int 256
# 2019-04-15 07:33:14.272 UTC [viperutil] getKeysRecursively -> DEBU 017 Found map[string]interface{} value for peer.BCCSP.SW.FileKeyStore
# 2019-04-15 07:33:14.272 UTC [viperutil] unmarshalJSON -> DEBU 018 Unmarshal JSON: value cannot be unmarshalled: unexpected end of JSON input
# 2019-04-15 07:33:14.272 UTC [viperutil] getKeysRecursively -> DEBU 019 Found real value for peer.BCCSP.SW.FileKeyStore.KeyStore setting to string
# 2019-04-15 07:33:14.272 UTC [viperutil] EnhancedExactUnmarshalKey -> DEBU 01a map[peer.BCCSP:map[PKCS11:map[Pin:<nil> Hash:<nil> Security:<nil> FileKeyStore:map[KeyStore:<nil>] Library:<nil> Label:<nil>] Default:SW SW:map[Hash:SHA2 Security:256 FileKeyStore:map[KeyStore:]]]]
# 2019-04-15 07:33:14.272 UTC [bccsp_sw] openKeyStore -> DEBU 01b KeyStore opened at [/opt/gopath/src/github.com/hyperledger/fabric/peer/crypto/peerOrganizations/hospital.organ.com/users/Admin@hospital.organ.com/msp/keystore]...done
# 2019-04-15 07:33:14.272 UTC [bccsp] initBCCSP -> DEBU 01c Initialize BCCSP [SW]
# 2019-04-15 07:33:14.272 UTC [msp] getPemMaterialFromDir -> DEBU 01d Reading directory /opt/gopath/src/github.com/hyperledger/fabric/peer/crypto/peerOrganizations/hospital.organ.com/users/Admin@hospital.organ.com/msp/signcerts
# 2019-04-15 07:33:14.272 UTC [msp] getPemMaterialFromDir -> DEBU 01e Inspecting file /opt/gopath/src/github.com/hyperledger/fabric/peer/crypto/peerOrganizations/hospital.organ.com/users/Admin@hospital.organ.com/msp/signcerts/Admin@hospital.organ.com-cert.pem
# 2019-04-15 07:33:14.272 UTC [msp] getPemMaterialFromDir -> DEBU 01f Reading directory /opt/gopath/src/github.com/hyperledger/fabric/peer/crypto/peerOrganizations/hospital.organ.com/users/Admin@hospital.organ.com/msp/cacerts
# 2019-04-15 07:33:14.273 UTC [msp] getPemMaterialFromDir -> DEBU 020 Inspecting file /opt/gopath/src/github.com/hyperledger/fabric/peer/crypto/peerOrganizations/hospital.organ.com/users/Admin@hospital.organ.com/msp/cacerts/ca.hospital.organ.com-cert.pem
# 2019-04-15 07:33:14.273 UTC [msp] getPemMaterialFromDir -> DEBU 021 Reading directory /opt/gopath/src/github.com/hyperledger/fabric/peer/crypto/peerOrganizations/hospital.organ.com/users/Admin@hospital.organ.com/msp/admincerts
# 2019-04-15 07:33:14.273 UTC [msp] getPemMaterialFromDir -> DEBU 022 Inspecting file /opt/gopath/src/github.com/hyperledger/fabric/peer/crypto/peerOrganizations/hospital.organ.com/users/Admin@hospital.organ.com/msp/admincerts/Admin@hospital.organ.com-cert.pem
# 2019-04-15 07:33:14.273 UTC [msp] getPemMaterialFromDir -> DEBU 023 Reading directory /opt/gopath/src/github.com/hyperledger/fabric/peer/crypto/peerOrganizations/hospital.organ.com/users/Admin@hospital.organ.com/msp/intermediatecerts
# 2019-04-15 07:33:14.273 UTC [msp] getMspConfig -> DEBU 024 Intermediate certs folder not found at [/opt/gopath/src/github.com/hyperledger/fabric/peer/crypto/peerOrganizations/hospital.organ.com/users/Admin@hospital.organ.com/msp/intermediatecerts]. Skipping. [stat /opt/gopath/src/github.com/hyperledger/fabric/peer/crypto/peerOrganizations/hospital.organ.com/users/Admin@hospital.organ.com/msp/intermediatecerts: no such file or directory]
# 2019-04-15 07:33:14.273 UTC [msp] getPemMaterialFromDir -> DEBU 025 Reading directory /opt/gopath/src/github.com/hyperledger/fabric/peer/crypto/peerOrganizations/hospital.organ.com/users/Admin@hospital.organ.com/msp/tlscacerts
# 2019-04-15 07:33:14.273 UTC [msp] getPemMaterialFromDir -> DEBU 026 Inspecting file /opt/gopath/src/github.com/hyperledger/fabric/peer/crypto/peerOrganizations/hospital.organ.com/users/Admin@hospital.organ.com/msp/tlscacerts/tlsca.hospital.organ.com-cert.pem
# 2019-04-15 07:33:14.273 UTC [msp] getPemMaterialFromDir -> DEBU 027 Reading directory /opt/gopath/src/github.com/hyperledger/fabric/peer/crypto/peerOrganizations/hospital.organ.com/users/Admin@hospital.organ.com/msp/tlsintermediatecerts
# 2019-04-15 07:33:14.273 UTC [msp] getMspConfig -> DEBU 028 TLS intermediate certs folder not found at [/opt/gopath/src/github.com/hyperledger/fabric/peer/crypto/peerOrganizations/hospital.organ.com/users/Admin@hospital.organ.com/msp/tlsintermediatecerts]. Skipping. [stat /opt/gopath/src/github.com/hyperledger/fabric/peer/crypto/peerOrganizations/hospital.organ.com/users/Admin@hospital.organ.com/msp/tlsintermediatecerts: no such file or directory]
# 2019-04-15 07:33:14.273 UTC [msp] getPemMaterialFromDir -> DEBU 029 Reading directory /opt/gopath/src/github.com/hyperledger/fabric/peer/crypto/peerOrganizations/hospital.organ.com/users/Admin@hospital.organ.com/msp/crls
# 2019-04-15 07:33:14.273 UTC [msp] getMspConfig -> DEBU 02a crls folder not found at [/opt/gopath/src/github.com/hyperledger/fabric/peer/crypto/peerOrganizations/hospital.organ.com/users/Admin@hospital.organ.com/msp/crls]. Skipping. [stat /opt/gopath/src/github.com/hyperledger/fabric/peer/crypto/peerOrganizations/hospital.organ.com/users/Admin@hospital.organ.com/msp/crls: no such file or directory]
# 2019-04-15 07:33:14.273 UTC [msp] getMspConfig -> DEBU 02b MSP configuration file not found at [/opt/gopath/src/github.com/hyperledger/fabric/peer/crypto/peerOrganizations/hospital.organ.com/users/Admin@hospital.organ.com/msp/config.yaml]: [stat /opt/gopath/src/github.com/hyperledger/fabric/peer/crypto/peerOrganizations/hospital.organ.com/users/Admin@hospital.organ.com/msp/config.yaml: no such file or directory]
# 2019-04-15 07:33:14.274 UTC [msp] newBccspMsp -> DEBU 02c Creating BCCSP-based MSP instance
# 2019-04-15 07:33:14.274 UTC [msp] New -> DEBU 02d Creating Cache-MSP instance
# 2019-04-15 07:33:14.274 UTC [msp] loadLocaMSP -> DEBU 02e Created new local MSP
# 2019-04-15 07:33:14.274 UTC [msp] Setup -> DEBU 02f Setting up MSP instance HospitalMSP
# 2019-04-15 07:33:14.274 UTC [msp.identity] newIdentity -> DEBU 030 Creating identity instance for cert -----BEGIN CERTIFICATE-----
# MIICSzCCAfGgAwIBAgIQU4qTV5R82xpwIMB7YpBlFjAKBggqhkjOPQQDAjB3MQsw
# CQYDVQQGEwJVUzETMBEGA1UECBMKQ2FsaWZvcm5pYTEWMBQGA1UEBxMNU2FuIEZy
# YW5jaXNjbzEbMBkGA1UEChMSaG9zcGl0YWwub3JnYW4uY29tMR4wHAYDVQQDExVj
# YS5ob3NwaXRhbC5vcmdhbi5jb20wHhcNMTkwNDE0MTUyMzAwWhcNMjkwNDExMTUy
# MzAwWjB3MQswCQYDVQQGEwJVUzETMBEGA1UECBMKQ2FsaWZvcm5pYTEWMBQGA1UE
# BxMNU2FuIEZyYW5jaXNjbzEbMBkGA1UEChMSaG9zcGl0YWwub3JnYW4uY29tMR4w
# HAYDVQQDExVjYS5ob3NwaXRhbC5vcmdhbi5jb20wWTATBgcqhkjOPQIBBggqhkjO
# PQMBBwNCAATZ5vsoXd6S7qQepN3XR2UXQHUx9BrR7kX/FloGJVI8bKnvT4Q6UwcY
# b5/d2P6Jp8Fuei9hgbFo/0wIYUasFBTTo18wXTAOBgNVHQ8BAf8EBAMCAaYwDwYD
# VR0lBAgwBgYEVR0lADAPBgNVHRMBAf8EBTADAQH/MCkGA1UdDgQiBCCf1++Alds/
# vGFZ055MBVUu2+RX+UUSneViD6RxhBzBWTAKBggqhkjOPQQDAgNIADBFAiEApdy+
# Wdf4Y5F9rS+O4C9LBRqc8GlLs2VDcpBF5yLDkVQCIEPdafKNbHfhTaHQnGJYenuQ
# P53HJKU5b/vQVuQKFsLp
# -----END CERTIFICATE-----
# 2019-04-15 07:33:14.276 UTC [msp.identity] newIdentity -> DEBU 031 Creating identity instance for cert -----BEGIN CERTIFICATE-----
# MIICMDCCAdegAwIBAgIRALw4dHY58zRGeYaNhtI3gNswCgYIKoZIzj0EAwIwdzEL
# MAkGA1UEBhMCVVMxEzARBgNVBAgTCkNhbGlmb3JuaWExFjAUBgNVBAcTDVNhbiBG
# cmFuY2lzY28xGzAZBgNVBAoTEmhvc3BpdGFsLm9yZ2FuLmNvbTEeMBwGA1UEAxMV
# Y2EuaG9zcGl0YWwub3JnYW4uY29tMB4XDTE5MDQxNDE1MjMwMFoXDTI5MDQxMTE1
# MjMwMFowbjELMAkGA1UEBhMCVVMxEzARBgNVBAgTCkNhbGlmb3JuaWExFjAUBgNV
# BAcTDVNhbiBGcmFuY2lzY28xDzANBgNVBAsTBmNsaWVudDEhMB8GA1UEAwwYQWRt
# aW5AaG9zcGl0YWwub3JnYW4uY29tMFkwEwYHKoZIzj0CAQYIKoZIzj0DAQcDQgAE
# Ir9YIB2VmaoPd56B/RvDDXvkr14/AJy1XhxU58wJBv6oO3VX4cEXa95I6gMMDBWY
# JXpoz8Fo0gaKLmDjP8sWfaNNMEswDgYDVR0PAQH/BAQDAgeAMAwGA1UdEwEB/wQC
# MAAwKwYDVR0jBCQwIoAgn9fvgJXbP7xhWdOeTAVVLtvkV/lFEp3lYg+kcYQcwVkw
# CgYIKoZIzj0EAwIDRwAwRAIgbQmN5J8qhBGspO//vM5xyCVo6mdmPWAl0Un7Ku3w
# kUoCIE05EJDFTrVEDCzLhgG99cEeLd0HKpnkqo24hi76LmlF
# -----END CERTIFICATE-----
# 2019-04-15 07:33:14.287 UTC [msp.identity] newIdentity -> DEBU 032 Creating identity instance for cert -----BEGIN CERTIFICATE-----
# MIICMDCCAdegAwIBAgIRALw4dHY58zRGeYaNhtI3gNswCgYIKoZIzj0EAwIwdzEL
# MAkGA1UEBhMCVVMxEzARBgNVBAgTCkNhbGlmb3JuaWExFjAUBgNVBAcTDVNhbiBG
# cmFuY2lzY28xGzAZBgNVBAoTEmhvc3BpdGFsLm9yZ2FuLmNvbTEeMBwGA1UEAxMV
# Y2EuaG9zcGl0YWwub3JnYW4uY29tMB4XDTE5MDQxNDE1MjMwMFoXDTI5MDQxMTE1
# MjMwMFowbjELMAkGA1UEBhMCVVMxEzARBgNVBAgTCkNhbGlmb3JuaWExFjAUBgNV
# BAcTDVNhbiBGcmFuY2lzY28xDzANBgNVBAsTBmNsaWVudDEhMB8GA1UEAwwYQWRt
# aW5AaG9zcGl0YWwub3JnYW4uY29tMFkwEwYHKoZIzj0CAQYIKoZIzj0DAQcDQgAE
# Ir9YIB2VmaoPd56B/RvDDXvkr14/AJy1XhxU58wJBv6oO3VX4cEXa95I6gMMDBWY
# JXpoz8Fo0gaKLmDjP8sWfaNNMEswDgYDVR0PAQH/BAQDAgeAMAwGA1UdEwEB/wQC
# MAAwKwYDVR0jBCQwIoAgn9fvgJXbP7xhWdOeTAVVLtvkV/lFEp3lYg+kcYQcwVkw
# CgYIKoZIzj0EAwIDRwAwRAIgbQmN5J8qhBGspO//vM5xyCVo6mdmPWAl0Un7Ku3w
# kUoCIE05EJDFTrVEDCzLhgG99cEeLd0HKpnkqo24hi76LmlF
# -----END CERTIFICATE-----
# 2019-04-15 07:33:14.287 UTC [bccsp_sw] loadPrivateKey -> DEBU 033 Loading private key [f7e28adcfb51da33b5a72eb8c8a9c1faf841cbd877826566cf2166ed382df031] at [/opt/gopath/src/github.com/hyperledger/fabric/peer/crypto/peerOrganizations/hospital.organ.com/users/Admin@hospital.organ.com/msp/keystore/f7e28adcfb51da33b5a72eb8c8a9c1faf841cbd877826566cf2166ed382df031_sk]...
# 2019-04-15 07:33:14.287 UTC [msp.identity] newIdentity -> DEBU 034 Creating identity instance for cert -----BEGIN CERTIFICATE-----
# MIICMDCCAdegAwIBAgIRALw4dHY58zRGeYaNhtI3gNswCgYIKoZIzj0EAwIwdzEL
# MAkGA1UEBhMCVVMxEzARBgNVBAgTCkNhbGlmb3JuaWExFjAUBgNVBAcTDVNhbiBG
# cmFuY2lzY28xGzAZBgNVBAoTEmhvc3BpdGFsLm9yZ2FuLmNvbTEeMBwGA1UEAxMV
# Y2EuaG9zcGl0YWwub3JnYW4uY29tMB4XDTE5MDQxNDE1MjMwMFoXDTI5MDQxMTE1
# MjMwMFowbjELMAkGA1UEBhMCVVMxEzARBgNVBAgTCkNhbGlmb3JuaWExFjAUBgNV
# BAcTDVNhbiBGcmFuY2lzY28xDzANBgNVBAsTBmNsaWVudDEhMB8GA1UEAwwYQWRt
# aW5AaG9zcGl0YWwub3JnYW4uY29tMFkwEwYHKoZIzj0CAQYIKoZIzj0DAQcDQgAE
# Ir9YIB2VmaoPd56B/RvDDXvkr14/AJy1XhxU58wJBv6oO3VX4cEXa95I6gMMDBWY
# JXpoz8Fo0gaKLmDjP8sWfaNNMEswDgYDVR0PAQH/BAQDAgeAMAwGA1UdEwEB/wQC
# MAAwKwYDVR0jBCQwIoAgn9fvgJXbP7xhWdOeTAVVLtvkV/lFEp3lYg+kcYQcwVkw
# CgYIKoZIzj0EAwIDRwAwRAIgbQmN5J8qhBGspO//vM5xyCVo6mdmPWAl0Un7Ku3w
# kUoCIE05EJDFTrVEDCzLhgG99cEeLd0HKpnkqo24hi76LmlF
# -----END CERTIFICATE-----
# 2019-04-15 07:33:14.314 UTC [msp] setupSigningIdentity -> DEBU 035 Signing identity expires at 2029-04-11 15:23:00 +0000 UTC
# 2019-04-15 07:33:14.314 UTC [msp] Validate -> DEBU 036 MSP HospitalMSP validating identity
# 2019-04-15 07:33:14.316 UTC [grpc] DialContext -> DEBU 037 parsed scheme: ""
# 2019-04-15 07:33:14.316 UTC [grpc] DialContext -> DEBU 038 scheme "" not registered, fallback to default scheme
# 2019-04-15 07:33:14.316 UTC [grpc] watcher -> DEBU 039 ccResolverWrapper: sending new addresses to cc: [{peer1.histocompatibility.organ.com:7051 0  <nil>}]
# 2019-04-15 07:33:14.316 UTC [grpc] switchBalancer -> DEBU 03a ClientConn switching balancer to "pick_first"
# 2019-04-15 07:33:14.317 UTC [grpc] HandleSubConnStateChange -> DEBU 03b pickfirstBalancer: HandleSubConnStateChange: 0xc0004be3e0, CONNECTING
# 2019-04-15 07:33:14.320 UTC [grpc] HandleSubConnStateChange -> DEBU 03c pickfirstBalancer: HandleSubConnStateChange: 0xc0004be3e0, READY
# 2019-04-15 07:33:14.321 UTC [grpc] DialContext -> DEBU 03d parsed scheme: ""
# 2019-04-15 07:33:14.321 UTC [grpc] DialContext -> DEBU 03e scheme "" not registered, fallback to default scheme
# 2019-04-15 07:33:14.322 UTC [grpc] watcher -> DEBU 03f ccResolverWrapper: sending new addresses to cc: [{peer1.histocompatibility.organ.com:7051 0  <nil>}]
# 2019-04-15 07:33:14.322 UTC [grpc] switchBalancer -> DEBU 040 ClientConn switching balancer to "pick_first"
# 2019-04-15 07:33:14.322 UTC [grpc] HandleSubConnStateChange -> DEBU 041 pickfirstBalancer: HandleSubConnStateChange: 0xc00044b4d0, CONNECTING
# 2019-04-15 07:33:14.330 UTC [grpc] HandleSubConnStateChange -> DEBU 042 pickfirstBalancer: HandleSubConnStateChange: 0xc00044b4d0, READY
# 2019-04-15 07:33:14.331 UTC [grpc] DialContext -> DEBU 043 parsed scheme: ""
# 2019-04-15 07:33:14.331 UTC [grpc] DialContext -> DEBU 044 scheme "" not registered, fallback to default scheme
# 2019-04-15 07:33:14.331 UTC [grpc] watcher -> DEBU 045 ccResolverWrapper: sending new addresses to cc: [{peer0.histocompatibility.organ.com:7051 0  <nil>}]
# 2019-04-15 07:33:14.331 UTC [grpc] switchBalancer -> DEBU 046 ClientConn switching balancer to "pick_first"
# 2019-04-15 07:33:14.331 UTC [grpc] HandleSubConnStateChange -> DEBU 047 pickfirstBalancer: HandleSubConnStateChange: 0xc0003bd550, CONNECTING
# 2019-04-15 07:33:14.335 UTC [grpc] HandleSubConnStateChange -> DEBU 048 pickfirstBalancer: HandleSubConnStateChange: 0xc0003bd550, READY
# 2019-04-15 07:33:14.336 UTC [grpc] DialContext -> DEBU 049 parsed scheme: ""
# 2019-04-15 07:33:14.336 UTC [grpc] DialContext -> DEBU 04a scheme "" not registered, fallback to default scheme
# 2019-04-15 07:33:14.336 UTC [grpc] watcher -> DEBU 04b ccResolverWrapper: sending new addresses to cc: [{peer0.histocompatibility.organ.com:7051 0  <nil>}]
# 2019-04-15 07:33:14.336 UTC [grpc] switchBalancer -> DEBU 04c ClientConn switching balancer to "pick_first"
# 2019-04-15 07:33:14.336 UTC [grpc] HandleSubConnStateChange -> DEBU 04d pickfirstBalancer: HandleSubConnStateChange: 0xc00050c020, CONNECTING
# 2019-04-15 07:33:14.340 UTC [grpc] HandleSubConnStateChange -> DEBU 04e pickfirstBalancer: HandleSubConnStateChange: 0xc00050c020, READY
# 2019-04-15 07:33:14.341 UTC [grpc] DialContext -> DEBU 04f parsed scheme: ""
# 2019-04-15 07:33:14.341 UTC [grpc] DialContext -> DEBU 050 scheme "" not registered, fallback to default scheme
# 2019-04-15 07:33:14.341 UTC [grpc] watcher -> DEBU 051 ccResolverWrapper: sending new addresses to cc: [{peer0.hospital.organ.com:7051 0  <nil>}]
# 2019-04-15 07:33:14.341 UTC [grpc] switchBalancer -> DEBU 052 ClientConn switching balancer to "pick_first"
# 2019-04-15 07:33:14.341 UTC [grpc] HandleSubConnStateChange -> DEBU 053 pickfirstBalancer: HandleSubConnStateChange: 0xc0002faa50, CONNECTING
# 2019-04-15 07:33:14.344 UTC [grpc] HandleSubConnStateChange -> DEBU 054 pickfirstBalancer: HandleSubConnStateChange: 0xc0002faa50, READY
# 2019-04-15 07:33:14.346 UTC [grpc] DialContext -> DEBU 055 parsed scheme: ""
# 2019-04-15 07:33:14.346 UTC [grpc] DialContext -> DEBU 056 scheme "" not registered, fallback to default scheme
# 2019-04-15 07:33:14.346 UTC [grpc] watcher -> DEBU 057 ccResolverWrapper: sending new addresses to cc: [{peer0.hospital.organ.com:7051 0  <nil>}]
# 2019-04-15 07:33:14.347 UTC [grpc] switchBalancer -> DEBU 058 ClientConn switching balancer to "pick_first"
# 2019-04-15 07:33:14.347 UTC [grpc] HandleSubConnStateChange -> DEBU 059 pickfirstBalancer: HandleSubConnStateChange: 0xc000587300, CONNECTING
# 2019-04-15 07:33:14.350 UTC [grpc] HandleSubConnStateChange -> DEBU 05a pickfirstBalancer: HandleSubConnStateChange: 0xc000587300, READY
# 2019-04-15 07:33:14.351 UTC [grpc] DialContext -> DEBU 05b parsed scheme: ""
# 2019-04-15 07:33:14.351 UTC [grpc] DialContext -> DEBU 05c scheme "" not registered, fallback to default scheme
# 2019-04-15 07:33:14.351 UTC [grpc] watcher -> DEBU 05d ccResolverWrapper: sending new addresses to cc: [{peer1.hospital.organ.com:7051 0  <nil>}]
# 2019-04-15 07:33:14.351 UTC [grpc] switchBalancer -> DEBU 05e ClientConn switching balancer to "pick_first"
# 2019-04-15 07:33:14.351 UTC [grpc] HandleSubConnStateChange -> DEBU 05f pickfirstBalancer: HandleSubConnStateChange: 0xc0003eb980, CONNECTING
# 2019-04-15 07:33:14.354 UTC [grpc] HandleSubConnStateChange -> DEBU 060 pickfirstBalancer: HandleSubConnStateChange: 0xc0003eb980, READY
# 2019-04-15 07:33:14.355 UTC [grpc] DialContext -> DEBU 061 parsed scheme: ""
# 2019-04-15 07:33:14.355 UTC [grpc] DialContext -> DEBU 062 scheme "" not registered, fallback to default scheme
# 2019-04-15 07:33:14.355 UTC [grpc] watcher -> DEBU 063 ccResolverWrapper: sending new addresses to cc: [{peer1.hospital.organ.com:7051 0  <nil>}]
# 2019-04-15 07:33:14.355 UTC [grpc] switchBalancer -> DEBU 064 ClientConn switching balancer to "pick_first"
# 2019-04-15 07:33:14.355 UTC [grpc] HandleSubConnStateChange -> DEBU 065 pickfirstBalancer: HandleSubConnStateChange: 0xc000141710, CONNECTING
# 2019-04-15 07:33:14.358 UTC [grpc] HandleSubConnStateChange -> DEBU 066 pickfirstBalancer: HandleSubConnStateChange: 0xc000141710, READY
# 2019-04-15 07:33:14.359 UTC [grpc] DialContext -> DEBU 067 parsed scheme: ""
# 2019-04-15 07:33:14.359 UTC [grpc] DialContext -> DEBU 068 scheme "" not registered, fallback to default scheme
# 2019-04-15 07:33:14.359 UTC [grpc] watcher -> DEBU 069 ccResolverWrapper: sending new addresses to cc: [{peer0.gp.organ.com:7051 0  <nil>}]
# 2019-04-15 07:33:14.359 UTC [grpc] switchBalancer -> DEBU 06a ClientConn switching balancer to "pick_first"
# 2019-04-15 07:33:14.360 UTC [grpc] HandleSubConnStateChange -> DEBU 06b pickfirstBalancer: HandleSubConnStateChange: 0xc00049af40, CONNECTING
# 2019-04-15 07:33:14.362 UTC [grpc] HandleSubConnStateChange -> DEBU 06c pickfirstBalancer: HandleSubConnStateChange: 0xc00049af40, READY
# 2019-04-15 07:33:14.363 UTC [grpc] DialContext -> DEBU 06d parsed scheme: ""
# 2019-04-15 07:33:14.363 UTC [grpc] DialContext -> DEBU 06e scheme "" not registered, fallback to default scheme
# 2019-04-15 07:33:14.363 UTC [grpc] watcher -> DEBU 06f ccResolverWrapper: sending new addresses to cc: [{peer0.gp.organ.com:7051 0  <nil>}]
# 2019-04-15 07:33:14.363 UTC [grpc] switchBalancer -> DEBU 070 ClientConn switching balancer to "pick_first"
# 2019-04-15 07:33:14.364 UTC [grpc] HandleSubConnStateChange -> DEBU 071 pickfirstBalancer: HandleSubConnStateChange: 0xc000587f90, CONNECTING
# 2019-04-15 07:33:14.367 UTC [grpc] HandleSubConnStateChange -> DEBU 072 pickfirstBalancer: HandleSubConnStateChange: 0xc000587f90, READY
# 2019-04-15 07:33:14.368 UTC [grpc] DialContext -> DEBU 073 parsed scheme: ""
# 2019-04-15 07:33:14.368 UTC [grpc] DialContext -> DEBU 074 scheme "" not registered, fallback to default scheme
# 2019-04-15 07:33:14.369 UTC [grpc] watcher -> DEBU 075 ccResolverWrapper: sending new addresses to cc: [{peer1.gp.organ.com:7051 0  <nil>}]
# 2019-04-15 07:33:14.369 UTC [grpc] switchBalancer -> DEBU 076 ClientConn switching balancer to "pick_first"
# 2019-04-15 07:33:14.369 UTC [grpc] HandleSubConnStateChange -> DEBU 077 pickfirstBalancer: HandleSubConnStateChange: 0xc0004ad990, CONNECTING
# 2019-04-15 07:33:14.373 UTC [grpc] HandleSubConnStateChange -> DEBU 078 pickfirstBalancer: HandleSubConnStateChange: 0xc0004ad990, READY
# 2019-04-15 07:33:14.376 UTC [grpc] DialContext -> DEBU 079 parsed scheme: ""
# 2019-04-15 07:33:14.377 UTC [grpc] DialContext -> DEBU 07a scheme "" not registered, fallback to default scheme
# 2019-04-15 07:33:14.377 UTC [grpc] watcher -> DEBU 07b ccResolverWrapper: sending new addresses to cc: [{peer1.gp.organ.com:7051 0  <nil>}]
# 2019-04-15 07:33:14.377 UTC [grpc] switchBalancer -> DEBU 07c ClientConn switching balancer to "pick_first"
# 2019-04-15 07:33:14.377 UTC [grpc] HandleSubConnStateChange -> DEBU 07d pickfirstBalancer: HandleSubConnStateChange: 0xc00063d820, CONNECTING
# 2019-04-15 07:33:14.380 UTC [grpc] HandleSubConnStateChange -> DEBU 07e pickfirstBalancer: HandleSubConnStateChange: 0xc00063d820, READY
# 2019-04-15 07:33:14.381 UTC [grpc] DialContext -> DEBU 07f parsed scheme: ""
# 2019-04-15 07:33:14.386 UTC [grpc] DialContext -> DEBU 080 scheme "" not registered, fallback to default scheme
# 2019-04-15 07:33:14.386 UTC [grpc] watcher -> DEBU 081 ccResolverWrapper: sending new addresses to cc: [{peer0.opo.organ.com:7051 0  <nil>}]
# 2019-04-15 07:33:14.386 UTC [grpc] switchBalancer -> DEBU 082 ClientConn switching balancer to "pick_first"
# 2019-04-15 07:33:14.386 UTC [grpc] HandleSubConnStateChange -> DEBU 083 pickfirstBalancer: HandleSubConnStateChange: 0xc00050c380, CONNECTING
# 2019-04-15 07:33:14.391 UTC [grpc] HandleSubConnStateChange -> DEBU 084 pickfirstBalancer: HandleSubConnStateChange: 0xc00050c380, READY
# 2019-04-15 07:33:14.392 UTC [grpc] DialContext -> DEBU 085 parsed scheme: ""
# 2019-04-15 07:33:14.392 UTC [grpc] DialContext -> DEBU 086 scheme "" not registered, fallback to default scheme
# 2019-04-15 07:33:14.392 UTC [grpc] watcher -> DEBU 087 ccResolverWrapper: sending new addresses to cc: [{peer0.opo.organ.com:7051 0  <nil>}]
# 2019-04-15 07:33:14.393 UTC [grpc] switchBalancer -> DEBU 088 ClientConn switching balancer to "pick_first"
# 2019-04-15 07:33:14.393 UTC [grpc] HandleSubConnStateChange -> DEBU 089 pickfirstBalancer: HandleSubConnStateChange: 0xc0001405d0, CONNECTING
# 2019-04-15 07:33:14.398 UTC [grpc] HandleSubConnStateChange -> DEBU 08a pickfirstBalancer: HandleSubConnStateChange: 0xc0001405d0, READY
# 2019-04-15 07:33:14.400 UTC [grpc] DialContext -> DEBU 08b parsed scheme: ""
# 2019-04-15 07:33:14.400 UTC [grpc] DialContext -> DEBU 08c scheme "" not registered, fallback to default scheme
# 2019-04-15 07:33:14.400 UTC [grpc] watcher -> DEBU 08d ccResolverWrapper: sending new addresses to cc: [{peer1.opo.organ.com:7051 0  <nil>}]
# 2019-04-15 07:33:14.400 UTC [grpc] switchBalancer -> DEBU 08e ClientConn switching balancer to "pick_first"
# 2019-04-15 07:33:14.400 UTC [grpc] HandleSubConnStateChange -> DEBU 08f pickfirstBalancer: HandleSubConnStateChange: 0xc000383ae0, CONNECTING
# 2019-04-15 07:33:14.404 UTC [grpc] HandleSubConnStateChange -> DEBU 090 pickfirstBalancer: HandleSubConnStateChange: 0xc000383ae0, READY
# 2019-04-15 07:33:14.405 UTC [grpc] DialContext -> DEBU 091 parsed scheme: ""
# 2019-04-15 07:33:14.405 UTC [grpc] DialContext -> DEBU 092 scheme "" not registered, fallback to default scheme
# 2019-04-15 07:33:14.405 UTC [grpc] watcher -> DEBU 093 ccResolverWrapper: sending new addresses to cc: [{peer1.opo.organ.com:7051 0  <nil>}]
# 2019-04-15 07:33:14.405 UTC [grpc] switchBalancer -> DEBU 094 ClientConn switching balancer to "pick_first"
# 2019-04-15 07:33:14.405 UTC [grpc] HandleSubConnStateChange -> DEBU 095 pickfirstBalancer: HandleSubConnStateChange: 0xc0004b2580, CONNECTING
# 2019-04-15 07:33:14.407 UTC [grpc] HandleSubConnStateChange -> DEBU 096 pickfirstBalancer: HandleSubConnStateChange: 0xc0004b2580, READY
# 2019-04-15 07:33:14.408 UTC [msp] GetDefaultSigningIdentity -> DEBU 097 Obtaining default signing identity
# 2019-04-15 07:33:14.409 UTC [grpc] DialContext -> DEBU 098 parsed scheme: ""
# 2019-04-15 07:33:14.409 UTC [grpc] DialContext -> DEBU 099 scheme "" not registered, fallback to default scheme
# 2019-04-15 07:33:14.410 UTC [grpc] watcher -> DEBU 09a ccResolverWrapper: sending new addresses to cc: [{orderer.organ.com:7050 0  <nil>}]
# 2019-04-15 07:33:14.410 UTC [grpc] switchBalancer -> DEBU 09b ClientConn switching balancer to "pick_first"
# 2019-04-15 07:33:14.411 UTC [grpc] HandleSubConnStateChange -> DEBU 09c pickfirstBalancer: HandleSubConnStateChange: 0xc0003bc4c0, CONNECTING
# 2019-04-15 07:33:14.414 UTC [grpc] HandleSubConnStateChange -> DEBU 09d pickfirstBalancer: HandleSubConnStateChange: 0xc0003bc4c0, READY
# 2019-04-15 07:33:14.415 UTC [msp.identity] Sign -> DEBU 09e Sign: plaintext: 0AD2070A6E08031A0C08BAE7D0E50510...09726561644F7267616E0A0431323331
# 2019-04-15 07:33:14.415 UTC [msp.identity] Sign -> DEBU 09f Sign: digest: C31833CF6DD3EC11034A4E0640ADB9D223CCFE0A90673C56A3DE565C9DF6B203
# 2019-04-15 07:33:14.495 UTC [msp.identity] Sign -> DEBU 0a0 Sign: plaintext: 0AD2070A6E08031A0C08BAE7D0E50510...D4A7C59D9E10E7400C5C3D22A3007380
# 2019-04-15 07:33:14.495 UTC [msp.identity] Sign -> DEBU 0a1 Sign: digest: C764248F9FD2B3312198585F498C4583191073ED942208B187E097F176517BC7
# 2019-04-15 07:33:14.504 UTC [chaincodeCmd] chaincodeInvokeOrQuery -> DEBU 0a2 ESCC invoke result: version:1 response:<status:200 payload:"{\"docType\":\"organ\",\"organID\":\"1231\",\"type\":\"heard\",\"donorInfo\":\"{\\\"num_ki_tx\\\": 36695585, \\\"pa_discard_cd_ostxt\\\": \\\"npgfxozcalvnnvzeztffxibmpkzjhfhooefrufjbvzkrhkizpo\\\", \\\"cardiac_output_cath_post_don\\\": 22930718, \\\"hist_oth_drug_don\\\": \\\"z\\\", \\\"kil_reason_ostxt\\\": \\\"idtytafvcdftglvtwlhriyywxceryshqrrbrxuawuimdqqkrqy\\\", \\\"ins2_disposition\\\": 15268362, \\\"ins1_reason_cd\\\": 99311362, \\\"rt_ki_pump_ty\\\": 9750260, \\\"lis2_back_tbl_flush\\\": 78330444, \\\"pcwp_init_don\\\": 12111900, \\\"hypertens_dur_don\\\": 60974435, \\\"region\\\": 21239455, \\\"lub_discard_cd\\\": 63867131, \\\"lur_discard_cd_ostxt\\\": \\\"aodukzrfcfzlpwkavifujqcvdeoynhicokizuhefidclqnfszr\\\", \\\"cvp_cath_post_don\\\": 21466655, \\\"ethnicity_don\\\": 61200277, \\\"in_final_flush\\\": 59564084, \\\"pt_oth1_ostxt_don\\\": \\\"hqpqwewlbhmzagrlipuhijarslsfdzhdwdpyenfhmjtaddjqfwfgawthpzevxshdhxbefjidipx\\\", \\\"hbv_dna\\\": \\\"bw\\\", \\\"pulm_inf_don\\\": 82167164, \\\"ins2_initial_flush\\\": 86481245, \\\"pt_oth2_ostxt_don\\\": \\\"rdcbgctuhebtihevgglysigbgbwbfblgekpywgltbtsbruocinrkkvnughmjbcaoyxwsjzpwueg\\\", \\\"li_reason_ostxt\\\": \\\"rzwfgkdpqlurafnpamljedbluypcfrgglbkgmxgfkwofmdpndn\\\", \\\"ins1_back_tbl_flush_ostxt\\\": \\\
ichzxppreg\\\", \\\"htlv_nat\\\": \\\"qt\\\", \\\"lub_initial_flush\\\": 69293558, \\\"in_initial_flush\\\": 96831039, \\\"li_discard_cd\\\": 41795820, \\\"pco2_don\\\": 57715768, \\\"hba1c\\\": 77364861, \\\"lis2_final_flush_ostxt\\\": \\\"yvnufqcitkuxyqrqztxvdgxnvlxatxnmktbjteqiwgsuyrwvhi\\\", \\\"lur_discard_cd\\\": 36371760, \\\"pas1_discard_cd\\\": 17626292, \\\"pa_final_flush_ostxt\\\": \\\"twrvxftuy ...
# 2019-04-15 07:33:14.505 UTC [chaincodeCmd] chaincodeInvokeOrQuery -> INFO 0a3 Chaincode invoke successful. result: status:200 payload:"{\"docType\":\"organ\",\"organID\":\"1231\",\"type\":\"heard\",\"donorInfo\":\"{\\\"num_ki_tx\\\": 36695585, \\\"pa_discard_cd_ostxt\\\": \\\"npgfxozcalvnnvzeztffxibmpkzjhfhooefrufjbvzkrhkizpo\\\", \\\"cardiac_output_cath_post_don\\\": 22930718, \\\"hist_oth_drug_don\\\": \\\"z\\\", \\\"kil_reason_ostxt\\\": \\\"idtytafvcdftglvtwlhriyywxceryshqrrbrxuawuimdqqkrqy\\\", \\\"ins2_disposition\\\": 15268362, \\\"ins1_reason_cd\\\": 99311362, \\\"rt_ki_pump_ty\\\": 9750260, \\\"lis2_back_tbl_flush\\\": 78330444, \\\"pcwp_init_don\\\": 12111900, \\\"hypertens_dur_don\\\": 60974435, \\\"region\\\": 21239455, \\\"lub_discard_cd\\\": 63867131, \\\"lur_discard_cd_ostxt\\\": \\\"aodukzrfcfzlpwkavifujqcvdeoynhicokizuhefidclqnfszr\\\", \\\"cvp_cath_post_don\\\": 21466655, \\\"ethnicity_don\\\": 61200277, \\\"in_final_flush\\\": 59564084, \\\"pt_oth1_ostxt_don\\\": \\\"hqpqwewlbhmzagrlipuhijarslsfdzhdwdpyenfhmjtaddjqfwfgawthpzevxshdhxbefjidipx\\\", \\\"hbv_dna\\\": \\\"bw\\\", \\\"pulm_inf_don\\\": 82167164, \\\"ins2_initial_flush\\\": 86481245, \\\"pt_oth2_ostxt_don\\\": \\\"rdcbgctuhebtihevgglysigbgbwbfblgekpywgltbtsbruocinrkkvnughmjbcaoyxwsjzpwueg\\\", \\\"li_reason_ostxt\\\": \\\"rzwfgkdpqlurafnpamljedbluypcfrgglbkgmxgfkwofmdpndn\\\", \\\"ins1_back_tbl_flush_ostxt\\\": \\\"bytooabifqyxorcshkzwfflfmvkbbtpfscnydqkdgqbmwwbujz\\\", \\\"lub_back_tbl_flush\\\": 99277980, \\\"hr_final_flush_ostxt\\\": \\\"qfgmyfqgofcvnvsjhsqgxmypzgcqtlxzdipkfswxrcrtkwmfkc\\\", \\\"abn_lvh_don\\\": \\\"p\\\", \\\"abn_valves_don\\\": \\\"j\\\", \\\"pas1_final_flush\\\": 64705910, \\\"pas2_disposition\\\": 24899082, \\\"kir_final_flush\\\": 43745763, \\\"citizen_